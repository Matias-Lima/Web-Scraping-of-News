# %%
#News API

# %%
import requests
import json

url = ('https://newsapi.org/v2/everything?'
       'q=BBDC4&'
       'from=2023-03-25&'
       'sortBy=popularity&'
       'apiKey=#')

response = requests.get(url)

# Check if response status code is 200 (OK)
if response.status_code == 200:
    # Get a list of articles from the response JSON
    articles = response.json()['articles']
    # Loop through each article and extract the title
    for article in articles:
        title = article['title']
        data = article['publishedAt']
        description = article['description']
        print(title)
        print(description)
        print(data)
        print(f"source: {article['source']['name']}")
        print()


print(response.json())
# Out:
# None
# A renda variável, que inclui ações, fundos e outros investimentos é vista por muitas pessoas como uma opção mais cara. Mas não é necessário ter muito dinheiro para começar a investir. Dá para começar com pouco, até entender como esse segmento funciona e q
# 2023-04-13T17:22:06Z
# source: Uol.com.br
#
# Moraes autoriza Bradesco (BBDC4) a recolher e-mails de diretores da Americanas (AMER3)
# Ministro do STF havia suspendido apreensão em fevereiro por conta de que havia risco da quebra do sigilo entre cliente e advogados
# The post Moraes autoriza Bradesco (BBDC4) a recolher e-mails de diretores da Americanas (AMER3) appeared first on InfoMoney.
# 2023-04-03T20:33:13Z
# source: InfoMoney
#
# Ibovespa hoje: acompanhe o que movimenta Bolsa, Dólar e Juros Ao Vivo
# Bolsas sobem às vésperas de inflação nos EUA
# The post Ibovespa hoje: acompanhe o que movimenta Bolsa, Dólar e Juros Ao Vivo appeared first on InfoMoney.
# 2023-04-11T09:55:21Z
# source: InfoMoney
#
# Carrefour (CRFB3), Hapvida (HAPV3) e Soma (SOMA3) disparam 4%, com Ibovespa positivo nesta manhã
# Carrefour (CRFB3), Hapvida (HAPV3) e Soma (SOMA3) disparam 4%, com Ibovespa positivo nesta manhã; MRV (MRVE3), Gol (GOLL4) e Méliuz (CASH3) destacavam-se negativamente na ponta oposta
# 2023-04-20T14:58:00Z
# source: Spacemoney.com.br
#
# Natura (NTCO3), Americanas (AMER3), Kepler Weber (KEPL3) e Enauta (ENAT3): destaques corporativos
# Natura (NTCO3), Americanas (AMER3), Kepler Weber (KEPL3) e Enauta (ENAT3): destaques corporativos; Veja aqui as principais notícias das grandes empresas brasileiras, entre avisos aos acionistas, comunicados ao mercado, fatos...
# 2023-04-04T10:22:00Z
# source: Spacemoney.com.br
#
# {'status': 'ok', 'totalResults': 5, 'articles': [{'source': {'id': None, 'name': 'Uol.com.br'}, 'author': 'Fernando Barbosa', 'title': None, 'description': 'A renda variável, que inclui ações, fundos e outros investimentos é vista por muitas pessoas como uma opção mais cara. Mas não é necessário ter muito dinheiro para começar a investir. Dá para começar com pouco, até entender como esse segmento funciona e q', 'url': 'https://economia.uol.com.br/mais/ultimas-noticias/2023/04/13/investir-ate-cinquenta-reais-renda-variavel.htm', 'urlToImage': 'https://conteudo.imguol.com.br/c/noticias/16/2022/05/13/acoes-cotacoes-bolsa-de-valores-trader-sobe-e-desce-da-bolsa-investimentos-aplicacoes-1652449705856_v2_615x300.jpg', 'publishedAt': '2023-04-13T17:22:06Z', 'content': 'A renda variável, que inclui ações, fundos e outros investimentos é vista por muitas pessoas como uma opção mais cara. Mas não é necessário ter muito dinheiro para começar a investir. Dá para começar… [+4996 chars]'}, {'source': {'id': 'info-money', 'name': 'InfoMoney'}, 'author': 'Rikardy Tooge', 'title': 'Moraes autoriza Bradesco (BBDC4) a recolher e-mails de diretores da Americanas (AMER3)', 'description': 'Ministro do STF havia suspendido apreensão em fevereiro por conta de que havia risco da quebra do sigilo entre cliente e advogados\nThe post Moraes autoriza Bradesco (BBDC4) a recolher e-mails de diretores da Americanas (AMER3) appeared first on InfoMoney.', 'url': 'https://www.infomoney.com.br/negocios/moraes-autoriza-bradesco-bbdc4-a-recolher-e-mails-de-diretores-da-americanas-amer3/', 'urlToImage': 'https://www.infomoney.com.br/wp-content/uploads/2019/06/alexandre-de-moraes-5.jpg?quality=70', 'publishedAt': '2023-04-03T20:33:13Z', 'content': '© 2000-2023 InfoMoney. Todos os direitos reservados.\r\nO InfoMoney preza a qualidade da informação e atesta a apuração de todo o conteúdo produzido por sua equipe, ressaltando, no entanto, que não faz… [+1194 chars]'}, {'source': {'id': 'info-money', 'name': 'InfoMoney'}, 'author': 'Equipe InfoMoney', 'title': 'Ibovespa hoje: acompanhe o que movimenta Bolsa, Dólar e Juros Ao Vivo', 'description': 'Bolsas sobem às vésperas de inflação nos EUA\nThe post Ibovespa hoje: acompanhe o que movimenta Bolsa, Dólar e Juros Ao Vivo appeared first on InfoMoney.', 'url': 'https://www.infomoney.com.br/mercados/ibovespa-hoje-bolsa-de-valores-ao-vivo-11042023/', 'urlToImage': 'https://www.infomoney.com.br/wp-content/uploads/2022/07/alta1.jpg?quality=70', 'publishedAt': '2023-04-11T09:55:21Z', 'content': 'update 7h07 Cerca de 20 acordos bilaterais deverão ser assinados durante a visita de Lula à China\r\nO presidente Luiz Inácio Lula da Silva deve assinar cerca de 20 acordos durante viagem à China que c… [+12393 chars]'}, {'source': {'id': None, 'name': 'Spacemoney.com.br'}, 'author': 'Space Money', 'title': 'Carrefour (CRFB3), Hapvida (HAPV3) e Soma (SOMA3) disparam 4%, com Ibovespa positivo nesta manhã', 'description': 'Carrefour (CRFB3), Hapvida (HAPV3) e Soma (SOMA3) disparam 4%, com Ibovespa positivo nesta manhã; MRV (MRVE3), Gol (GOLL4) e Méliuz (CASH3) destacavam-se negativamente na ponta oposta', 'url': 'https://www.spacemoney.com.br/geral/altas-e-quedas-do-ibovespa-20042023-crfb3-hapv3-soma3/192140/', 'urlToImage': 'https://cdn.spacemoney.com.br/upload/dn_arquivo/2020/11/pexels-pixabay-210607.jpg', 'publishedAt': '2023-04-20T14:58:00Z', 'content': 'Menu\r\nBusca\r\nquinta, 20 de abril de 2023\r\nSpaceMercadoMRV (MRVE3), Gol (GOLL4) e Méliuz (CASH3) destacavam-se negativamente na ponta oposta\r\n20 abril 2023 - 11h58Por Lucas de Andrade\r\nÀs 11:38 desta … [+9227 chars]'}, {'source': {'id': None, 'name': 'Spacemoney.com.br'}, 'author': 'Space Money', 'title': 'Natura (NTCO3), Americanas (AMER3), Kepler Weber (KEPL3) e Enauta (ENAT3): destaques corporativos', 'description': 'Natura (NTCO3), Americanas (AMER3), Kepler Weber (KEPL3) e Enauta (ENAT3): destaques corporativos; Veja aqui as principais notícias das grandes empresas brasil ...
